# %% [markdown]
# # KL Dra

# %%
import json
import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
from lightkurve.lightcurve import LightCurve as LC
from lightkurve import TessTargetPixelFile

import eleanor

from bokeh.plotting import output_notebook, figure, show
from bokeh.models import HoverTool, tools,ColumnDataSource, Whisker, ColorBar, LinearColorMapper
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
with open('response.json','r') as JSON:
    rdic = json.load(JSON)
kldra = rdic['KL Dra']

# %%
kldra['ra']
kldracoord = "{} +{}".format(kldra['ra'],kldra['dec'])
print(kldracoord)
# Out:
# 291.1595 +59.696305555555554

# %%
lk.search_tesscut(kldracoord)
# Out:
# SearchResult containing 5 data products.
#
#  #   observation           target_name          productFilename distance
# --- -------------- ---------------------------- --------------- --------
#   0 TESS Sector 14 291.1595 +59.696305555555554         TESSCut      0.0
#   1 TESS Sector 15 291.1595 +59.696305555555554         TESSCut      0.0
#   2 TESS Sector 16 291.1595 +59.696305555555554         TESSCut      0.0
#   3 TESS Sector 17 291.1595 +59.696305555555554         TESSCut      0.0
#   4 TESS Sector 18 291.1595 +59.696305555555554         TESSCut      0.0

# %%
tpf = lk.search_tesscut(kldracoord,sector=14).download(cutout_size=11)

# %%
tpf.plot()

# %% [markdown]
# # Define the aperture and plot it

# %%
aper = np.zeros(tpf.shape[1:], dtype=np.int)
#aper[5:6, 5:6] = 1 #
#aper[4:6, 5] = 1
aper[5, 6] = 1 #y luego x


tpf.plot(aperture_mask=aper, mask_color='red');
n_target_pixels = aper.sum()
print(n_target_pixels)
# Out:
# 1

# %% [markdown]
# ## Create a light-curve

# %%
target_lc = tpf.to_lightcurve(aperture_mask=aper.astype(bool))
target_lc.plot(label='Target + background');

# %%
background_mask = ~tpf.create_threshold_mask(threshold=0.00001, reference_pixel=None)
tpf.plot(aperture_mask=background_mask, mask_color='w');
n_background_pixels = background_mask.sum()
print(n_background_pixels)
# Out:
# 61

# %%
tpf.interact_sky()
# Out:
# <script src="http://localhost:42685/autoload.js?bokeh-autoload-element=1045&bokeh-absolute-url=http://localhost:42685&resources=none" id="1045"></script>
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=1045&bokeh-absolute-url=http://localhost:42685&resources=none (127.0.0.1)
# HTTPServerRequest(protocol='http', host='localhost:42685', method='GET', uri='/autoload.js?bokeh-autoload-element=1045&bokeh-absolute-url=http://localhost:42685&resources=none', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connection.py", line 157, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/util/connection.py", line 84, in create_connection
#     raise err
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/util/connection.py", line 74, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connectionpool.py", line 672, in urlopen
#     chunked=chunked,
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connectionpool.py", line 387, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/http/client.py", line 1252, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/http/client.py", line 1298, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/http/client.py", line 1247, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/http/client.py", line 966, in send
#     self.connect()
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connection.py", line 184, in connect
#     conn = self._new_conn()
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connection.py", line 164, in _new_conn
#     % (self.host, self.timeout),
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x7fd6262dc4d0>, 'Connection to vizier.u-strasbg.fr timed out. (connect timeout=60)')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/connectionpool.py", line 720, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/urllib3/util/retry.py", line 436, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='vizier.u-strasbg.fr', port=80): Max retries exceeded with url: /viz-bin/votable (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fd6262dc4d0>, 'Connection to vizier.u-strasbg.fr timed out. (connect timeout=60)'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/web.py", line 1699, in _execute
#     result = await result
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/bokeh/server/views/session_handler.py", line 79, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/bokeh/server/contexts.py", line 222, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/lightkurve/interact.py", line 666, in create_interact_ui
#     magnitude_limit=magnitude_limit)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/lightkurve/interact.py", line 222, in add_gaia_figure_elements
#     radius=Angle(np.max(tpf.shape[1:]) * pix_scale, "arcsec"))
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/astroquery/utils/class_or_instance.py", line 25, in f
#     return self.fn(obj, *args, **kwds)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/astroquery/utils/process_asyncs.py", line 26, in newmethod
#     response = getattr(self, async_method_name)(*args, **kwargs)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/astroquery/vizier/core.py", line 442, in query_region_async
#     data=data_payload, timeout=self.TIMEOUT, cache=cache)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/astroquery/query.py", line 246, in _request
#     verify=verify)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/astroquery/query.py", line 66, in request
#     stream=stream, auth=auth, verify=verify)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/requests/adapters.py", line 504, in send
#     raise ConnectTimeout(e, request=request)
# requests.exceptions.ConnectTimeout: HTTPConnectionPool(host='vizier.u-strasbg.fr', port=80): Max retries exceeded with url: /viz-bin/votable (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7fd6262dc4d0>, 'Connection to vizier.u-strasbg.fr timed out. (connect timeout=60)'))
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=1045&bokeh-absolute-url=http://localhost:42685&resources=none (127.0.0.1) 60195.77ms

# %%
#tpf.interact()

# %% [markdown]
# ## The amount of background seen in the target aperture is the background flux per pixel times the number of pixels in the target aperture.

# %%
background_lc_per_pixel = tpf.to_lightcurve(aperture_mask=background_mask) / n_background_pixels
background_estimate_lc = background_lc_per_pixel * n_target_pixels

# %% [markdown]
# ## nanpercentile
#
# Compute the qth percentile of the data along the specified axis, while ignoring nan values.
#
# The second number is the percentile to compute, which must be between 0 and 100 inclusive.
#
# If q is a single percentile and axis=None, then the result is a scalar.

# %%
common_normalization = np.nanpercentile(target_lc.flux, 10)
ax = (target_lc / common_normalization).plot(normalize=False, label='Target + Background', lw=1);
(background_estimate_lc / common_normalization +0).plot(ax=ax, normalize=False, label='Background',
                                                        ylabel='Normalized, shifted flux');

# %%
corrected_lc = target_lc - background_estimate_lc.flux
corrected_lc.plot();

# %% [markdown]
# # Removes the low frequency trend using scipy’s Savitzky-Golay filter.

# %%
flat_lc = corrected_lc.flatten(window_length=401)
flat_lc.plot();

# %%
lcdic = {'time':flat_lc.time,
        "flatflux":flat_lc.flux}
source = ColumnDataSource(data=lcdic)

p = figure(plot_width=900, plot_height=500)
    

#Tool to get wavelength
hover2 = HoverTool(
        tooltips=[
            ('Date', '(@time{0,0.000})')
        ]
    )


p.add_tools(hover2)

p.line('time','flatflux',source=source)
show(p)
# Out:
#   <div class="bk-root" id="4c11bcc6-5202-422a-b324-42d80f761ccf" data-root-id="1004"></div>

# %% [markdown]
# # Sector 14 with Eleanor

# %%
star = eleanor.Source(coords=(kldra['ra'],kldra['dec']), sector=14, tc=True)
data = eleanor.TargetData(star,height=11, width=11)
# Out:
# /home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/eleanor/targetdata.py:383: UserWarning: WARNING: Making a TPF smaller than (9,9) may provide inadequate results.
#   warnings.warn('WARNING: Making a TPF smaller than (9,9) may provide inadequate results.')
# /home/mmarcano/anaconda3/envs/ele/lib/python3.7/site-packages/eleanor/targetdata.py:393: UserWarning: WARNING: Making a TPF smaller than (9,9) may provide inadequate results.
#   warnings.warn('WARNING: Making a TPF smaller than (9,9) may provide inadequate results.')

# %%
vis = eleanor.Visualize(data)
vis.aperture_contour()

# %%
q = data.quality == 0
lk = LC(data.time[q], data.corr_flux[q]).plot()
