# %%
#from IPython.display import Image
import eleanor
import numpy as np
import matplotlib.pyplot as plt
from lightkurve.lightcurve import LightCurve as LC
from lightkurve import TessTargetPixelFile

# %%
# Look in tesscut what sectos and in the first online when observed

# %%
star = eleanor.Source(coords=(33.0436 , 53.3608), sector=18, tc=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-9141c5ff92c4> in <module>
# ----> 1 star = eleanor.Source(coords=(33.0436 , 53.3608), sector=18, tc=True)
#
# ~/anaconda3/envs/ele/lib/python3.7/site-packages/eleanor/source.py in __init__(self, tic, gaia, coords, fn, sector, fn_dir, tc)
#     199             if tc == True:
#     200                 self.tesscut_size = 31
# --> 201                 self.locate_with_tesscut() # sets sector, camera, chip, postcard,
#     202                                   # position_on_chip, position_on_postcard
#     203
#
# ~/anaconda3/envs/ele/lib/python3.7/site-packages/eleanor/source.py in locate_with_tesscut(self)
#     343         self.sector = self.usr_sec
#     344
# --> 345         self.camera = sector_table[sector_table['sector'] == self.sector]['camera'].quantity[0]
# ...

# %%
data = eleanor.TargetData(star,height=15, width=15)

# %%
vis = eleanor.Visualize(data)

# %%
#vis.tess_the_movie()

# %%
vis.aperture_contour()

# %%
#filein = '/home/mmarcano/.eleanor/tesscut/tess-s0014-2-1_291.159500_59.696300_31x31_astrocut.fits'
#pix = TessTargetPixelFile(filein)

# %%
q = data.quality == 0
lk = LC(data.time[q], data.corr_flux[q]).plot()
